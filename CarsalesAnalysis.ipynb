# %% [markdown]
# # Carsales Data Analysis with Python Libraries

# %% [markdown]
# ## Importing the required libraries

# %%
#Importing needed libraries

import numpy as np
import pandas as pd

# %matplotlib inline 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading the data set

# %%
#loading the dataset
df = pd.read_csv("D:\Data Analysis\Projects\Car_Sales_Kaggle_Analysis.csv")
print("The dataframe is loaded succcessfully")
# Out:
# The dataframe is loaded succcessfully

# %%
df.head(6)
# Out:
#   Manufacturer    Model  Unit Sales    Price Year Resale Value Retention %  \
# 0        Acura  Integra       16919  $21,500           $16,360         76%
# 1        Acura       TL       39384  $28,400           $19,875         70%
# 2        Acura       RL        8588  $42,000           $29,725         71%
# 3         Audi       A4       20397  $23,990           $22,255         93%
# 4         Audi       A6       18780  $33,950           $23,555         69%
# 5         Audi       A8        1380  $62,000           $39,000         63%
#
#   Retention Value  Engine Size  Horsepower   HP Level  ... Curb Weight  \
# 0            GOOD          1.8         140  Medium HP  ...       2.639
# 1            GOOD          3.2         225  Medium HP  ...       3.517
# 2            GOOD          3.5         210  Medium HP  ...       3.850
# 3            GOOD          1.8         150  Medium HP  ...       2.998
# 4            GOOD          2.8         200  Medium HP  ...       3.561
# ...

# %%
df.shape
# Out:
# (155, 26)

# %% [markdown]
# ## A.Data Wrangling Section

# %% [markdown]
# ### Checking  for null values from the data set.
# We use the isnull() method together sum() to solve this problem.

# %%
#Checking for null values in the data set
df.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Unit Sales             0
# Price                  0
# Year Resale Value      0
# Retention %            0
# Retention Value        0
# Engine Size            0
# Horsepower             0
# HP Level               0
# Vehicle_type           0
# Fuel Efficiency        0
# Power Perf Factor      0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb Weight            0
# Fuel Capacity          0
# Latest Launch          0
# Unnamed: 19          155
# Unnamed: 20          155
# Unnamed: 21          155
# Unnamed: 22          155
# Unnamed: 23          155
# Unnamed: 24          155
# Unnamed: 25          155
# dtype: int64

# %% [markdown]
# ### Removing Null values from the data set.
# This is the method used to handle this:
#   dataframe.dropna(axis=1, how='all', inplace=True)

# %%
#Removing null values.
df.dropna(axis=1, how="all", inplace=True)
df.isnull().sum()
# Out:
# Manufacturer         0
# Model                0
# Unit Sales           0
# Price                0
# Year Resale Value    0
# Retention %          0
# Retention Value      0
# Engine Size          0
# Horsepower           0
# HP Level             0
# Vehicle_type         0
# Fuel Efficiency      0
# Power Perf Factor    0
# Wheelbase            0
# Width                0
# Length               0
# Curb Weight          0
# Fuel Capacity        0
# Latest Launch        0
# dtype: int64

# %%
#Checcking for data types
df.dtypes
# Out:
# Manufacturer          object
# Model                 object
# Unit Sales             int64
# Price                 object
# Year Resale Value     object
# Retention %           object
# Retention Value       object
# Engine Size          float64
# Horsepower             int64
# HP Level              object
# Vehicle_type          object
# Fuel Efficiency        int64
# Power Perf Factor    float64
# Wheelbase            float64
# Width                float64
# Length               float64
# Curb Weight          float64
# Fuel Capacity        float64
# Latest Launch         object
# dtype: object

# %% [markdown]
# ### Replacing $ with '' and , with '' in our data set.
# This will be handy in changing some of our columns data types for proper analysis

# %%
# Replacing $ with ''.
df['Price']=df['Price'].str.replace('$', '')
df['Year Resale Value']=df['Year Resale Value'].str.replace('$', '')
df['Retention %']=df['Retention %'].str.replace('%', '')

#Replacing , with ''
df['Price']=df['Price'].str.replace(',', '')
df['Year Resale Value']=df['Year Resale Value'].str.replace(',', '')
df.head(2)
# Out:
#   Manufacturer    Model  Unit Sales  Price Year Resale Value Retention %  \
# 0        Acura  Integra       16919  21500             16360          76
# 1        Acura       TL       39384  28400             19875          70
#
#   Retention Value  Engine Size  Horsepower   HP Level Vehicle_type  \
# 0            GOOD          1.8         140  Medium HP    Passenger
# 1            GOOD          3.2         225  Medium HP    Passenger
#
#    Fuel Efficiency  Power Perf Factor  Wheelbase  Width  Length  Curb Weight  \
# 0               28          58.280150      101.2   67.3   172.4        2.639
# 1               25          91.370778      108.1   70.3   192.9        3.517
#
#    Fuel Capacity Latest Launch
# 0           13.2    02/02/2012
# 1           17.2    03/06/2011

# %% [markdown]
# ### Changing data types for multiple columns.
# from object type to interger type.

# %%
# Converting multiple colunms to different type, from object type to interger type for better analysis
df[['Year Resale Value', 'Retention %', 'Price']] = df[['Year Resale Value',
                                        'Retention %', 'Price']].apply(pd.to_numeric, 
                                       )

# %%
df.dtypes
# Out:
# Manufacturer          object
# Model                 object
# Unit Sales             int64
# Price                  int64
# Year Resale Value      int64
# Retention %            int64
# Retention Value       object
# Engine Size          float64
# Horsepower             int64
# HP Level              object
# Vehicle_type          object
# Fuel Efficiency        int64
# Power Perf Factor    float64
# Wheelbase            float64
# Width                float64
# Length               float64
# Curb Weight          float64
# Fuel Capacity        float64
# Latest Launch         object
# dtype: object

# %%
#Checking for NaN values.
df.isna().sum()
# Out:
# Manufacturer         0
# Model                0
# Unit Sales           0
# Price                0
# Year Resale Value    0
# Retention %          0
# Retention Value      0
# Engine Size          0
# Horsepower           0
# HP Level             0
# Vehicle_type         0
# Fuel Efficiency      0
# Power Perf Factor    0
# Wheelbase            0
# Width                0
# Length               0
# Curb Weight          0
# Fuel Capacity        0
# Latest Launch        0
# dtype: int64

# %%
df.head()
# Out:
#   Manufacturer    Model  Unit Sales  Price  Year Resale Value  Retention %  \
# 0        Acura  Integra       16919  21500              16360           76
# 1        Acura       TL       39384  28400              19875           70
# 2        Acura       RL        8588  42000              29725           71
# 3         Audi       A4       20397  23990              22255           93
# 4         Audi       A6       18780  33950              23555           69
#
#   Retention Value  Engine Size  Horsepower   HP Level Vehicle_type  \
# 0            GOOD          1.8         140  Medium HP    Passenger
# 1            GOOD          3.2         225  Medium HP    Passenger
# 2            GOOD          3.5         210  Medium HP    Passenger
# 3            GOOD          1.8         150  Medium HP    Passenger
# 4            GOOD          2.8         200  Medium HP    Passenger
#
#    Fuel Efficiency  Power Perf Factor  Wheelbase  Width  Length  Curb Weight  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Manufacturer       155 non-null    object
#  1   Model              155 non-null    object
#  2   Unit Sales         155 non-null    int64
#  3   Price              155 non-null    int64
#  4   Year Resale Value  155 non-null    int64
#  5   Retention %        155 non-null    int64
#  6   Retention Value    155 non-null    object
#  7   Engine Size        155 non-null    float64
#  8   Horsepower         155 non-null    int64
#  9   HP Level           155 non-null    object
#  10  Vehicle_type       155 non-null    object
#  11  Fuel Efficiency    155 non-null    int64
#  12  Power Perf Factor  155 non-null    float64
#  13  Wheelbase          155 non-null    float64
#  14  Width              155 non-null    float64
#  15  Length             155 non-null    float64
# ...

# %%
#getting the number of columns 
df.columns.tolist()
# Out:
# ['Manufacturer',
#  'Model',
#  'Unit Sales',
#  'Price',
#  'Year Resale Value',
#  'Retention %',
#  'Retention Value',
#  'Engine Size',
#  'Horsepower',
#  'HP Level',
#  'Vehicle_type',
#  'Fuel Efficiency',
#  'Power Perf Factor',
#  'Wheelbase',
#  'Width',
#  'Length',
#  'Curb Weight',
#  'Fuel Capacity',
#  'Latest Launch']

# %%
# getting the list of indices. 
df.index
# Out:
# RangeIndex(start=0, stop=155, step=1)

# %%
#Setting maximum colunms and rows for the data
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
df.head()
# Out:
#   Manufacturer    Model  Unit Sales  Price  Year Resale Value  Retention %  \
# 0        Acura  Integra       16919  21500              16360           76
# 1        Acura       TL       39384  28400              19875           70
# 2        Acura       RL        8588  42000              29725           71
# 3         Audi       A4       20397  23990              22255           93
# 4         Audi       A6       18780  33950              23555           69
#
#   Retention Value  Engine Size  Horsepower   HP Level Vehicle_type  \
# 0            GOOD          1.8         140  Medium HP    Passenger
# 1            GOOD          3.2         225  Medium HP    Passenger
# 2            GOOD          3.5         210  Medium HP    Passenger
# 3            GOOD          1.8         150  Medium HP    Passenger
# 4            GOOD          2.8         200  Medium HP    Passenger
#
#    Fuel Efficiency  Power Perf Factor  Wheelbase  Width  Length  Curb Weight  \
# ...

# %%
#quick statistical summary for each colunm
df.describe()
# Out:
#           Unit Sales         Price  Year Resale Value  Retention %  \
# count     155.000000    155.000000         155.000000   155.000000
# mean    53245.832258  27455.270968       19138.277419    68.748387
# std     68397.550373  14456.610389       11621.397655    11.070960
# min       110.000000   9235.000000        5160.000000    48.000000
# 25%     14074.500000  18017.500000       11768.000000    61.000000
# 50%     29450.000000  22799.000000       15125.000000    66.000000
# 75%     68183.500000  31947.500000       21580.500000    76.000000
# max    540561.000000  85500.000000       67550.000000   100.000000
#
#        Engine Size  Horsepower  Fuel Efficiency  Power Perf Factor  \
# count   155.000000  155.000000       155.000000         155.000000
# mean      3.060000  185.696774        23.812903          77.043591
# std       1.047979   56.796444         4.268257          25.142664
# min       1.000000   55.000000        15.000000          23.276272
# ...

# %%
# Sorting dataset
df.sort_values('Manufacturer', axis=0, ascending=True, inplace=False, ignore_index=True).head(10)
# Out:
#   Manufacturer    Model  Unit Sales  Price  Year Resale Value  Retention %  \
# 0        Acura  Integra       16919  21500              16360           76
# 1        Acura       TL       39384  28400              19875           70
# 2        Acura       RL        8588  42000              29725           71
# 3         Audi       A4       20397  23990              22255           93
# 4         Audi       A6       18780  33950              23555           69
# 5         Audi       A8        1380  62000              39000           63
# 6          BMW     323i       19747  26990              24500           91
# 7          BMW     328i        9231  33400              28675           86
# 8          BMW     528i       17527  38900              36125           93
# 9        Buick  LeSabre       83257  27885              13360           48
#
#   Retention Value  Engine Size  Horsepower   HP Level Vehicle_type  \
# 0            GOOD          1.8         140  Medium HP    Passenger
# ...

# %%
df.head()
# Out:
#   Manufacturer    Model  Unit Sales  Price  Year Resale Value  Retention %  \
# 0        Acura  Integra       16919  21500              16360           76
# 1        Acura       TL       39384  28400              19875           70
# 2        Acura       RL        8588  42000              29725           71
# 3         Audi       A4       20397  23990              22255           93
# 4         Audi       A6       18780  33950              23555           69
#
#   Retention Value  Engine Size  Horsepower   HP Level Vehicle_type  \
# 0            GOOD          1.8         140  Medium HP    Passenger
# 1            GOOD          3.2         225  Medium HP    Passenger
# 2            GOOD          3.5         210  Medium HP    Passenger
# 3            GOOD          1.8         150  Medium HP    Passenger
# 4            GOOD          2.8         200  Medium HP    Passenger
#
#    Fuel Efficiency  Power Perf Factor  Wheelbase  Width  Length  Curb Weight  \
# ...

# %%
df.head()
# Out:
#   Manufacturer    Model  Unit Sales  Price  Year Resale Value  Retention %  \
# 0        Acura  Integra       16919  21500              16360           76
# 1        Acura       TL       39384  28400              19875           70
# 2        Acura       RL        8588  42000              29725           71
# 3         Audi       A4       20397  23990              22255           93
# 4         Audi       A6       18780  33950              23555           69
#
#   Retention Value  Engine Size  Horsepower   HP Level Vehicle_type  \
# 0            GOOD          1.8         140  Medium HP    Passenger
# 1            GOOD          3.2         225  Medium HP    Passenger
# 2            GOOD          3.5         210  Medium HP    Passenger
# 3            GOOD          1.8         150  Medium HP    Passenger
# 4            GOOD          2.8         200  Medium HP    Passenger
#
#    Fuel Efficiency  Power Perf Factor  Wheelbase  Width  Length  Curb Weight  \
# ...

# %%
df.head()
# Out:
#   Manufacturer    Model  Unit Sales  Price  Year Resale Value  Retention %  \
# 0        Acura  Integra       16919  21500              16360           76
# 1        Acura       TL       39384  28400              19875           70
# 2        Acura       RL        8588  42000              29725           71
# 3         Audi       A4       20397  23990              22255           93
# 4         Audi       A6       18780  33950              23555           69
#
#   Retention Value  Engine Size  Horsepower   HP Level Vehicle_type  \
# 0            GOOD          1.8         140  Medium HP    Passenger
# 1            GOOD          3.2         225  Medium HP    Passenger
# 2            GOOD          3.5         210  Medium HP    Passenger
# 3            GOOD          1.8         150  Medium HP    Passenger
# 4            GOOD          2.8         200  Medium HP    Passenger
#
#    Fuel Efficiency  Power Perf Factor  Wheelbase  Width  Length  Curb Weight  \
# ...

# %% [markdown]
# # B.Data Analysis Section

# %% [markdown]
#    ## 1. Cars Pricing Analysis
#  1. Is there a **correlation** between **car price and yearly resale value**?
#  1. Is there a **correlation** between **car price and engine size**?
#  2. Is there a **correlation** between **car price and fuel efficiency** ?
#  1. Is there a **correlation** between **car price and horsepower**?
#  2. Is there a **correlation** between **car price and unit sales** ?

# %%
#Price and Yearly Resale Value plot 

plt.figure(figsize=(10, 6))
sns.regplot(data=df, x='Year Resale Value', y='Price')
plt.ylim(0)
plt.xlim(0)
plt.title('Correlation between  yearly resale value and price')
plt.xlabel('Yearly Resale Value')
plt.ylabel('Price')

plt.show()

# %%
df[['Price','Year Resale Value']].corr()
# Out:
#                       Price  Year Resale Value
# Price              1.000000           0.957576
# Year Resale Value  0.957576           1.000000

# %% [markdown]
# #### Since the Correlation value is **0.9575**.This shows  ***a very strong correlation*** between yearly resale value and price

# %%
#Price and Engine size Value plot

plt.figure(figsize=(10, 6))
sns.regplot(data=df, x='Engine Size', y='Price')
plt.ylim(0)
plt.xlim(0)
plt.title('Correlation between  engine size and price')
plt.xlabel('Engine size')
plt.ylabel('Price')

plt.show()

# %%
df[['Price','Engine Size']].corr()
# Out:
#                 Price  Engine Size
# Price        1.000000     0.633639
# Engine Size  0.633639     1.000000

# %% [markdown]
# #### Since the Correlation value is **0.06336**.This shows  **a positive correlation** between engine size and price

# %%
#Price and Fuel efficiency plot

plt.figure(figsize=(10, 6))
sns.regplot(data=df, x='Fuel Efficiency', y='Price')
plt.ylim(0)
plt.xlim(0)
plt.title('Correlation between  fuel effiency and price')
plt.xlabel('Fuel efficiency')
plt.ylabel('Price')

plt.show()

# %%
df[['Price','Fuel Efficiency']].corr()
# Out:
#                     Price  Fuel Efficiency
# Price            1.000000        -0.488652
# Fuel Efficiency -0.488652         1.000000

# %% [markdown]
# #### Since the correlation value is **-0.04886.** This shows ***weak correlation*** between fuel efficiency and Price

# %%
#Price and Horsepower plot

plt.figure(figsize=(10, 6))
sns.regplot(data=df, x='Horsepower', y='Price')
plt.ylim(0)
plt.xlim(0)
plt.title('Correlation between horsepower and Price')
plt.xlabel('Horsepower')
plt.ylabel('Price')

plt.show()

# %%
#Price and Unit of sales plot

plt.figure(figsize=(10, 6))
sns.regplot(data=df, x='Unit Sales', y='Price')
plt.ylim(0)
plt.xlim(0)
plt.title('Correlation Between Unit Sales and Price')
plt.xlabel('Unit Sales')
plt.ylabel('Price')
plt.show()

# %%
df[['Unit Sales','Price']].corr()
# Out:
#             Unit Sales    Price
# Unit Sales     1.00000 -0.30484
# Price         -0.30484  1.00000

# %% [markdown]
# #### Since the correlation value is **-0.30484.** This shows ***weak correlation*** between Unit of Sales and Price

# %% [markdown]
# ## 2. Cars Engine Size Analysis
#  1. Is there a **correlation** between **engine size and horsepower**?
#  1. Is there a **correlation** between **engine size and yearly resale value**?
#  2. Is there a **correlation** between **engine size and fuel efficiency** ?
#  2. Is there a **correlation** between **engine size and unit of sales** ?

# %%
#Engine size and horsepower plot

plt.figure(figsize=(10, 6))
sns.regplot(data=df, x='Engine Size', y='Horsepower')
plt.ylim(0)
plt.xlim(0)
plt.title('Relationship between horsepower and engine size')
plt.xlabel('Engine size')
plt.ylabel('Horspower')

plt.show()

# %%
df[['Engine Size','Horsepower']].corr()
# Out:
#              Engine Size  Horsepower
# Engine Size     1.000000    0.838104
# Horsepower      0.838104    1.000000

# %% [markdown]
# #### Since the correlation value is **0.8381.** This shows ***strong correlation*** between engine size and horsepower

# %%
#Engine size and yearly resale value plot

plt.figure(figsize=(10, 6))
sns.regplot(data=df, x='Engine Size', y='Year Resale Value')
plt.ylim(0)
plt.xlim(0)
plt.title('Relationship between engine size and Yearly reasale value')
plt.xlabel('Engine size')
plt.ylabel('Yearly resale value')

plt.show()

# %%
df[['Engine Size','Year Resale Value']].corr()
# Out:
#                    Engine Size  Year Resale Value
# Engine Size           1.000000           0.513493
# Year Resale Value     0.513493           1.000000

# %% [markdown]
# #### Since the correlation value is **0.51349.** This shows ***good correlation*** between engine size and yearly resale value

# %%
#Engine size and fuel efficiency plot

plt.figure(figsize=(10, 6))
sns.regplot(data=df, x='Engine Size', y='Fuel Efficiency')
plt.ylim(0)
plt.xlim(0)
plt.title('Relationship between engine size and fuel efficiency')
plt.xlabel('Engine size')
plt.ylabel('Fuel efficiency')

plt.show()

# %%
df[['Engine Size','Fuel Efficiency']].corr()
# Out:
#                  Engine Size  Fuel Efficiency
# Engine Size         1.000000        -0.734066
# Fuel Efficiency    -0.734066         1.000000

# %% [markdown]
# #### Since the correlation value is **-0.7340.** This shows ***strong negative correlation*** between engine size and fuel efficiency

# %%
#Engine size and unit of sales plot

plt.figure(figsize=(10, 6))
sns.regplot(data=df, x='Engine Size', y='Unit Sales')
plt.ylim(0)
plt.xlim(0)
plt.title('Relationship between engine size and unit of sales')
plt.xlabel('Engine size')
plt.ylabel('Unit of sales')

plt.show()

# %%
df[['Engine Size','Unit Sales']].corr()
# Out:
#              Engine Size  Unit Sales
# Engine Size     1.000000    0.020499
# Unit Sales      0.020499    1.000000

# %% [markdown]
# #### Since the correlation value is **0.0204.** This shows ***very weak correlation*** between engine size and units of sale

# %%
df.head(2)
# Out:
#   Manufacturer    Model  Unit Sales  Price  Year Resale Value  Retention %  \
# 0        Acura  Integra       16919  21500              16360           76
# 1        Acura       TL       39384  28400              19875           70
#
#   Retention Value  Engine Size  Horsepower   HP Level Vehicle_type  \
# 0            GOOD          1.8         140  Medium HP    Passenger
# 1            GOOD          3.2         225  Medium HP    Passenger
#
#    Fuel Efficiency  Power Perf Factor  Wheelbase  Width  Length  Curb Weight  \
# 0               28          58.280150      101.2   67.3   172.4        2.639
# 1               25          91.370778      108.1   70.3   192.9        3.517
#
#    Fuel Capacity Latest Launch
# 0           13.2    02/02/2012
# 1           17.2    03/06/2011

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='HP Level', y='Unit Sales', hue='HP Level')
plt.ylim(0)
plt.xlim(0)
plt.title('Relationship between engine size and unit of sales')
plt.xlabel('Engine size')
plt.ylabel('Unit of sales')

plt.show()
